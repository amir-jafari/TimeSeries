# %% [markdown]
# # Demo of Helper Functions

# %%
### import packages
import os
import numpy as np

import TimeSeriesSRC as TS

# %% [markdown]
# ## Reading the data for the demo

# %%
def read_data(file):
    path = os.getcwd()
    path_file = ".." + os.path.sep + "testdata" + os.path.sep + file
    data = np.genfromtxt(path_file, delimiter=',')
    data = data.reshape(1,-1)
    return data

# %%
# Creating the object that contains the helper functions  
xtimeseries = TS.TimeSeries.TSAnalysis.TimesSeries()

# %%
xtimeseries.
